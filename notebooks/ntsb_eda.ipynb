# %% [markdown]
# # EDA on NTSB
#
# ## This notebook is for downloading and performing basic EDA on the NTSB data file.
#
# ### Data Source: https://www.ntsb.gov/_layouts/ntsb.aviation/index.aspx
# ### File Format: pipe delimited '|'

# %% [markdown]
# ### Import Python Libraries

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from urllib.request import urlretrieve

# %% [markdown]
# ### Download the data file from NTSB.

# %%
# create "data" sub directory (if not exists)
if not os.path.isdir("./data"):
    os.makedirs('./data')

data_file_uri = "http://app.ntsb.gov/aviationquery/Download.ashx?type=csv"
urlretrieve(data_file_uri, './data/AviationData.txt')
# Out:
# ('./data/AviationData.txt', <http.client.HTTPMessage at 0x214ab5c9df0>)

# %% [markdown]
# ### Import the downloaded data into Pandas dataframe.

# %%
filename = 'data/AviationData.txt' 
data = pd.read_csv(filename, delimiter='|')

# %% [markdown]
# ### Show some basic stats about the dataframe.

# %%
# row and column count
data.shape
# Out:
# (84778, 32)

# %%
# show the column names (note all the extraneous spaces in the column names)
data.columns
# Out:
# Index(['Event Id ', ' Investigation Type ', ' Accident Number ',
#        ' Event Date ', ' Location ', ' Country ', ' Latitude ', ' Longitude ',
#        ' Airport Code ', ' Airport Name ', ' Injury Severity ',
#        ' Aircraft Damage ', ' Aircraft Category ', ' Registration Number ',
#        ' Make ', ' Model ', ' Amateur Built ', ' Number of Engines ',
#        ' Engine Type ', ' FAR Description ', ' Schedule ',
#        ' Purpose of Flight ', ' Air Carrier ', ' Total Fatal Injuries ',
#        ' Total Serious Injuries ', ' Total Minor Injuries ',
#        ' Total Uninjured ', ' Weather Condition ', ' Broad Phase of Flight ',
#        ' Report Status ', ' Publication Date ', ' '],
#       dtype='object')

# %%
# What's up with the blank column at the end? Let's drop it.
data.drop(" ", axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84778 entries, 0 to 84777
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Event Id                  84778 non-null  object
#  1    Investigation Type       84778 non-null  object
#  2    Accident Number          84778 non-null  object
#  3    Event Date               84778 non-null  object
#  4    Location                 84778 non-null  object
#  5    Country                  84778 non-null  object
#  6    Latitude                 84778 non-null  object
#  7    Longitude                84778 non-null  object
#  8    Airport Code             84778 non-null  object
#  9    Airport Name             84778 non-null  object
#  10   Injury Severity          84778 non-null  object
#  11   Aircraft Damage          84778 non-null  object
#  12   Aircraft Category        84778 non-null  object
#  13   Registration Number      84778 non-null  object
#  14   Make                     84778 non-null  object
#  15   Model                    84778 non-null  object
#  16   Amateur Built            84778 non-null  object
#  17   Number of Engines        84778 non-null  object
#  18   Engine Type              84778 non-null  object
#  19   FAR Description          84778 non-null  object
#  20   Schedule                 84778 non-null  object
#  21   Purpose of Flight        84778 non-null  object
#  22   Air Carrier              84778 non-null  object
#  23   Total Fatal Injuries     84778 non-null  object
#  24   Total Serious Injuries   84778 non-null  object
#  25   Total Minor Injuries     84778 non-null  object
#  26   Total Uninjured          84778 non-null  object
#  27   Weather Condition        84778 non-null  object
#  28   Broad Phase of Flight    84778 non-null  object
#  29   Report Status            84778 non-null  object
#  30   Publication Date         84778 non-null  object
# dtypes: object(31)
# memory usage: 20.1+ MB

# %%
# summary statistics (with strings too)
data.describe(include="all")
# Out:
#               Event Id   Investigation Type   Accident Number    Event Date   \
# count             84778                84778             84778         84778
# unique            83539                    3             84778         13818
# top     20001212X19172             Accident        SEA85FA040    05/16/1982
# freq                  3                81222                 1            25
#
#               Location          Country   Latitude   Longitude   \
# count             84778            84778      84778       84778
# unique            26747              184      20645       22257
# top      ANCHORAGE, AK    United States
# freq                372            79146      54233       54242
#
#         Airport Code   Airport Name   ...  Purpose of Flight   Air Carrier   \
# count           84778          84778  ...               84778         84778
# unique          10048          23985  ...                  23          3056
# top                                   ...           Personal
# freq            36694          30885  ...               47358         80537
#
#         Total Fatal Injuries   Total Serious Injuries   Total Minor Injuries   \
# count                   84778                    84778                  84778
# unique                    128                       41                     64
# top                        0                        0                      0
# freq                    40061                    42631                  40028
#
#         Total Uninjured   Weather Condition   Broad Phase of Flight   \
# count              84778               84778                   84778
# unique               377                   4                      13
# top                   1                 VMC                 LANDING
# freq               23990               74538                   20795
#
#           Report Status   Publication Date
# count              84778              84778
# unique                 4               3984
# top      Probable Cause
# freq               77645              14530
#
# [4 rows x 31 columns]

# %%
# show the first 10 rows
data.head(10)
# Out:
#          Event Id   Investigation Type   Accident Number    Event Date   \
# 0  20200410X12023             Accident        ERA20CA151    04/10/2020
# 1  20200411X15400             Accident        CEN20LA145    04/10/2020
# 2  20200413X03920             Accident        CEN20CA146    04/10/2020
# 3  20200410X50413             Accident        ANC20CA042    04/10/2020
# 4  20200408X83712             Accident        CEN20LA143    04/07/2020
# 5  20200408X83126             Accident        ANC20CA041    04/07/2020
# 6  20200407X53436             Accident        CEN20CA144    04/06/2020
# 7  20200406X24210             Accident        CEN20CA138    04/02/2020
# 8  20200401X50400             Accident        ERA20CA146    04/01/2020
# 9  20200401X12025             Accident        ERA20CA143    04/01/2020
#
#            Location          Country     Latitude      Longitude   \
# 0      Townsend, TN    United States    35.570834      83.585000
# 1        Sidney, IA    United States    40.826111     -95.670278
# 2   Forth Worth, TX    United States    32.829167     -97.535000
# 3         Homer, AK    United States    59.645555    -151.476389
# 4     Pecan Gap, TX    United States
# 5    Chickaloon, AK    United States    61.539722    -147.134444
# 6       Seymour, TX    United States    33.646666     -99.259444
# 7        Hessel, MI    United States    46.035555     -84.417778
# 8     Hollywood, FL    United States    26.001111     -80.240833
# 9    Palm Coast, FL    United States    29.465278     -81.207778
#
#    Airport Code         Airport Name   ...    Purpose of Flight   \
# 0                                N/A   ...             Personal
# 1                                N/A   ...             Personal
# 2          2TE2                        ...             Personal
# 3           HOM                HOMER   ...             Personal
# 4                                      ...   Aerial Application
# 5                                N/A   ...             Personal
# 6                                      ...       Other Work Use
# 7           5Y1    Albert J Lindberg   ...             Personal
# 8           HWO          North Perry   ...        Instructional
# 9           FIN    Flagler Executive   ...        Instructional
#
#    Air Carrier   Total Fatal Injuries   Total Serious Injuries   \
# 0
# 1
# 2
# 3
# 4                                   1
# 5
# 6
# 7
# 8
# 9
#
#    Total Minor Injuries   Total Uninjured   Weather Condition   \
# 0
# 1                                       2                 VMC
# 2                     2                                   VMC
# 3                                       1
# 4                                                         VMC
# 5                                       2
# 6                                       1                 VMC
# 7                                       1                 VMC
# 8                                       3                 VMC
# 9                                       2                 VMC
#
#    Broad Phase of Flight   Report Status   Publication Date
# 0                            Preliminary         04/14/2020
# 1                            Preliminary         04/14/2020
# 2                            Preliminary         04/15/2020
# 3                            Preliminary         04/10/2020
# 4            MANEUVERING     Preliminary         04/15/2020
# 5                            Preliminary         04/08/2020
# 6                            Preliminary         04/15/2020
# 7                LANDING         Factual         04/15/2020
# 8                            Preliminary         04/14/2020
# 9              GO-AROUND         Factual         04/15/2020
#
# [10 rows x 31 columns]

# %% [markdown]
# ### Change the index to the "Event Date" column (as datetime)

# %%
# what is the current index?
data.index
# Out:
# RangeIndex(start=0, stop=84778, step=1)

# %%
# data.reset_index(inplace=True)
datetime_index = pd.DatetimeIndex(data.index)
data.set_index(' Event Date ', inplace=True)

# %%
# now what is the index?
data.index
# Out:
# DatetimeIndex(['1982-01-01', '1982-01-01', '1982-01-01', '1982-01-01',
#                '1982-01-01', '1983-01-01', '1983-01-01', '1983-01-01',
#                '1983-01-01', '1983-01-01',
#                ...
#                '2016-12-31', '2016-12-31', '2017-12-31', '2017-12-31',
#                '2018-12-31', '2019-12-31', '2019-12-31', '2019-12-31',
#                '2019-12-31', '2019-12-31'],
#               dtype='datetime64[ns]', name=' Event Date ', length=84778, freq=None)

# %%
data.index.isnull().sum()
data.index.isna().sum();

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 84778 entries, 1982-01-01 to 2019-12-31
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0    Accident Number          84778 non-null  object
#  1    Air Carrier              84778 non-null  object
#  2    Aircraft Category        84778 non-null  object
#  3    Aircraft Damage          84778 non-null  object
#  4    Airport Code             84778 non-null  object
#  5    Airport Name             84778 non-null  object
#  6    Amateur Built            84778 non-null  bool
#  7    Broad Phase of Flight    84778 non-null  object
#  8    Country                  84778 non-null  object
#  9    Engine Type              84778 non-null  object
#  10   FAR Description          84778 non-null  object
#  11   Injury Severity          84778 non-null  object
#  12   Investigation Type       84778 non-null  object
#  13   Latitude                 84778 non-null  object
#  14   Location                 84778 non-null  object
#  15   Longitude                84778 non-null  object
#  16   Make                     84778 non-null  object
#  17   Model                    84778 non-null  object
#  18   Number of Engines        84778 non-null  int8
#  19   Publication Date         0 non-null      datetime64[ns]
#  20   Purpose of Flight        84778 non-null  object
#  21   Registration Number      84778 non-null  object
#  22   Report Status            84778 non-null  object
#  23   Schedule                 84778 non-null  object
#  24   Total Fatal Injuries     84778 non-null  int16
#  25   Total Minor Injuries     84778 non-null  int16
#  26   Total Serious Injuries   84778 non-null  int8
#  27   Total Uninjured          84778 non-null  int16
#  28   Weather Condition        84778 non-null  object
#  29  Event Id                  84778 non-null  object
#  30  index                     84778 non-null  int64
#  31  level_0                   84778 non-null  int64
# dtypes: bool(1), datetime64[ns](1), int16(3), int64(2), int8(2), object(23)
# memory usage: 18.2+ MB

# %% [markdown]
# ### Change the data types of the columns

# %%
# data[' Latitude '] = pd.to_numeric(data[' Latitude '], downcast="float").fillna(0)
# data[' Longitude '] = pd.to_numeric(data[' Longitude '], downcast="float").fillna(0)

# Boolean
data[' Amateur Built '] = data[' Amateur Built '].astype(bool)
# Integers
data[' Number of Engines '] = pd.to_numeric(data[' Number of Engines '], downcast="integer", errors='coerce').fillna(0)
data[' Total Fatal Injuries '] = pd.to_numeric(data[' Total Fatal Injuries '], downcast="integer", errors='coerce').fillna(0)
data[' Total Serious Injuries '] = pd.to_numeric(data[' Total Serious Injuries '], downcast="integer", errors='coerce').fillna(0)
data[' Total Minor Injuries '] = pd.to_numeric(data[' Total Minor Injuries '], downcast="integer", errors='coerce').fillna(0)
data[' Total Uninjured '] = pd.to_numeric(data[' Total Uninjured '], downcast="integer", errors='coerce').fillna(0)
# DateTime
# data[' Event Date '] = pd.to_datetime(data[' Event Date '], format='%Y/%m/%d', errors='coerce')
data[' Publication Date '] = pd.to_datetime(data[' Publication Date '], format='%Y/%m/%d', errors='coerce')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84778 entries,  01/01/1982  to  12/31/2019
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0    Accident Number          84778 non-null  object
#  1    Air Carrier              84778 non-null  object
#  2    Aircraft Category        84778 non-null  object
#  3    Aircraft Damage          84778 non-null  object
#  4    Airport Code             84778 non-null  object
#  5    Airport Name             84778 non-null  object
#  6    Amateur Built            84778 non-null  bool
#  7    Broad Phase of Flight    84778 non-null  object
#  8    Country                  84778 non-null  object
#  9    Engine Type              84778 non-null  object
#  10   FAR Description          84778 non-null  object
#  11   Injury Severity          84778 non-null  object
#  12   Investigation Type       84778 non-null  object
#  13   Latitude                 84778 non-null  object
#  14   Location                 84778 non-null  object
#  15   Longitude                84778 non-null  object
#  16   Make                     84778 non-null  object
#  17   Model                    84778 non-null  object
#  18   Number of Engines        84778 non-null  int8
#  19   Publication Date         0 non-null      datetime64[ns]
#  20   Purpose of Flight        84778 non-null  object
#  21   Registration Number      84778 non-null  object
#  22   Report Status            84778 non-null  object
#  23   Schedule                 84778 non-null  object
#  24   Total Fatal Injuries     84778 non-null  int16
#  25   Total Minor Injuries     84778 non-null  int16
#  26   Total Serious Injuries   84778 non-null  int8
#  27   Total Uninjured          84778 non-null  int16
#  28   Weather Condition        84778 non-null  object
#  29  Event Id                  84778 non-null  object
# dtypes: bool(1), datetime64[ns](1), int16(3), int8(2), object(23)
# memory usage: 19.4+ MB

# %%
# data.reset_index(inplace=True)

# data[' Event Date '] = data[' Event Date '].astype("datetime64")
data[' Event Date '] = pd.to_datetime(data[' Event Date '], format='%Y/%m/%d', errors='coerce')

# data.sort_index(axis=1, inplace=True)
print(data.index)

# data[' Total Uninjured '].plot(title='# Total Uninjured')
# Out:
# RangeIndex(start=0, stop=84778, step=1)

# %% [markdown]
# ## Column Names
# `Index(['Event Id ', ' Investigation Type ', ' Accident Number ',
#        ' Event Date ', ' Location ', ' Country ', ' Latitude ', ' Longitude ',
#        ' Airport Code ', ' Airport Name ', ' Injury Severity ',
#        ' Aircraft Damage ', ' Aircraft Category ', ' Registration Number ',
#        ' Make ', ' Model ', ' Amateur Built ', ' Number of Engines ',
#        ' Engine Type ', ' FAR Description ', ' Schedule ',
#        ' Purpose of Flight ', ' Air Carrier ', ' Total Fatal Injuries ',
#        ' Total Serious Injuries ', ' Total Minor Injuries ',
#        ' Total Uninjured ', ' Weather Condition ', ' Broad Phase of Flight ',
#        ' Report Status ', ' Publication Date ', ' '],
#       dtype='object')`
